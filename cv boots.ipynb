# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.'],   

    'MPN':['AT-03076'],
    'SKU':['120822'],
    
    'FRONT/REAR':['REAR'],
    'INBOARD/OUTBOARD':['INBOARD']
}

list_models = [

    'KVF650 Brute Force 4x4',
    'KVF650 Brute Force 4x4i',
    'KVF750 Brute Force 4x4i',
    'KVF750 Brute Force 4x4i EPS',
    'KVF750 Brute Force 4x4i EPS Camo',

]

years = list(range(2009, 2014))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#         Make                             Model Vendor  \
# 0   Kawasaki            KVF650 Brute Force 4x4   NACH
# 1   Kawasaki           KVF650 Brute Force 4x4i   NACH
# 2   Kawasaki           KVF750 Brute Force 4x4i   NACH
# 3   Kawasaki       KVF750 Brute Force 4x4i EPS   NACH
# 4   Kawasaki  KVF750 Brute Force 4x4i EPS Camo   NACH
# 5   Kawasaki            KVF650 Brute Force 4x4   NACH
# 6   Kawasaki           KVF650 Brute Force 4x4i   NACH
# 7   Kawasaki           KVF750 Brute Force 4x4i   NACH
# 8   Kawasaki       KVF750 Brute Force 4x4i EPS   NACH
# 9   Kawasaki  KVF750 Brute Force 4x4i EPS Camo   NACH
# 10  Kawasaki            KVF650 Brute Force 4x4   NACH
# 11  Kawasaki           KVF650 Brute Force 4x4i   NACH
# 12  Kawasaki           KVF750 Brute Force 4x4i   NACH
# 13  Kawasaki       KVF750 Brute Force 4x4i EPS   NACH
# 14  Kawasaki  KVF750 Brute Force 4x4i EPS Camo   NACH
# 15  Kawasaki            KVF650 Brute Force 4x4   NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-3076frontorinboard.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; SERIAL # 9B500713'],   

    'MPN':['AT-03076'],
    'SKU':['120822'],
    
    'FRONT/REAR':['FRONT'],
    'INBOARD/OUTBOARD':['OUTBOARD']
}

list_models = [

    'KRF750 Teryx 4x4'


]

years = list(range(2009, 2013))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#        Make             Model Vendor                    Vendor Code  \
# 0  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
#
#    Product Type                                       Vendor Notes       MPN  \
# 0  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03076
# 1  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03076
# 2  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03076
# 3  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03076
#
#       SKU FRONT/REAR INBOARD/OUTBOARD  Year
# 0  120822      FRONT         OUTBOARD  2009
# 1  120822      FRONT         OUTBOARD  2010
# 2  120822      FRONT         OUTBOARD  2011
# 3  120822      FRONT         OUTBOARD  2012

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-3076front&OUTboard.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; SERIAL # 9B500713'],   

    'MPN':['AT-03076'],
    'SKU':['120822'],
    
    'FRONT/REAR':['REAR'],
    'INBOARD/OUTBOARD':['OUTBOARD']
}

list_models = [

'KVF650 Brute Force 4x4i',
'KVF750 Brute Force 4x4i',
'KVF750 Brute Force 4x4i EPS',
'KVF750 Brute Force 4x4i EPS Camo',



]

years = list(range(2009, 2024))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#         Make                             Model Vendor  \
# 0   Kawasaki           KVF650 Brute Force 4x4i   NACH
# 1   Kawasaki           KVF750 Brute Force 4x4i   NACH
# 2   Kawasaki       KVF750 Brute Force 4x4i EPS   NACH
# 3   Kawasaki  KVF750 Brute Force 4x4i EPS Camo   NACH
# 4   Kawasaki           KVF650 Brute Force 4x4i   NACH
# 5   Kawasaki           KVF750 Brute Force 4x4i   NACH
# 6   Kawasaki       KVF750 Brute Force 4x4i EPS   NACH
# 7   Kawasaki  KVF750 Brute Force 4x4i EPS Camo   NACH
# 8   Kawasaki           KVF650 Brute Force 4x4i   NACH
# 9   Kawasaki           KVF750 Brute Force 4x4i   NACH
# 10  Kawasaki       KVF750 Brute Force 4x4i EPS   NACH
# 11  Kawasaki  KVF750 Brute Force 4x4i EPS Camo   NACH
# 12  Kawasaki           KVF650 Brute Force 4x4i   NACH
# 13  Kawasaki           KVF750 Brute Force 4x4i   NACH
# 14  Kawasaki       KVF750 Brute Force 4x4i EPS   NACH
# 15  Kawasaki  KVF750 Brute Force 4x4i EPS Camo   NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-3076REAR-OUTBOARD.CSV"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500713'],   
    'MPN':['AT-03077'],
    'SKU':['120823'],
    
    'FRONT/REAR':['REAR'],
    'INBOARD/OUTBOARD':['OUTBOARD']
}

list_models = [

'KRF750 Teryx 4x4'



]

years = list(range(2009, 2012))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#        Make             Model Vendor                    Vendor Code  \
# 0  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
#
#    Product Type                                       Vendor Notes       MPN  \
# 0  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03077
# 1  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03077
# 2  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03077
#
#       SKU FRONT/REAR INBOARD/OUTBOARD  Year
# 0  120823       REAR         OUTBOARD  2009
# 1  120823       REAR         OUTBOARD  2010
# 2  120823       REAR         OUTBOARD  2011

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03077REAR-OUTBOARDSERIAL713.CSV"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500712'],   
    'MPN':['AT-03077'],
    'SKU':['120823'],
    
    'FRONT/REAR':['REAR'],
    'INBOARD/OUTBOARD':['OUTBOARD']
}

list_models = [

'KRF750 Teryx 4x4'



]

years = list(range(2009, 2012))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#        Make             Model Vendor                    Vendor Code  \
# 0  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
#
#    Product Type                                       Vendor Notes       MPN  \
# 0  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03077
# 1  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03077
# 2  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03077
#
#       SKU FRONT/REAR INBOARD/OUTBOARD  Year
# 0  120823       REAR         OUTBOARD  2009
# 1  120823       REAR         OUTBOARD  2010
# 2  120823       REAR         OUTBOARD  2011

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03077REAR-OUTBOARDSERIAL712.CSV"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500713'],   
    'MPN':['AT-03078'],
    'SKU':['120824'],
    
    'FRONT/REAR':['REAR'],
    'INBOARD/OUTBOARD':['INBOARD']
}

list_models = [

'KRF750 Teryx 4x4'



]

years = list(range(2008, 2012))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#        Make             Model Vendor                    Vendor Code  \
# 0  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
#
#    Product Type                                       Vendor Notes       MPN  \
# 0  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 1  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 2  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 3  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
#
#       SKU FRONT/REAR INBOARD/OUTBOARD  Year
# 0  120824       REAR          INBOARD  2008
# 1  120824       REAR          INBOARD  2009
# 2  120824       REAR          INBOARD  2010
# 3  120824       REAR          INBOARD  2011

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03078REAR-INBOARDSERIAL713.CSV"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500712'],   
    'MPN':['AT-03078'],
    'SKU':['120824'],
    
    'FRONT/REAR':['REAR'],
    'INBOARD/OUTBOARD':['INBOARD']
}

list_models = [

'KRF750 Teryx 4x4'



]

years = list(range(2008, 2012))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#        Make             Model Vendor                    Vendor Code  \
# 0  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
#
#    Product Type                                       Vendor Notes       MPN  \
# 0  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 1  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 2  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 3  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
#
#       SKU FRONT/REAR INBOARD/OUTBOARD  Year
# 0  120824       REAR          INBOARD  2008
# 1  120824       REAR          INBOARD  2009
# 2  120824       REAR          INBOARD  2010
# 3  120824       REAR          INBOARD  2011

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03078REAR-INBOARDSERIAL712.CSV"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

boots = {
    'Make':['Kawasaki'],
    'Model':['All Model'],
    'Vendor':['NACH'],
    'Vendor Code':['NACHMAN INTERNATIONAL CO. LTD'],
    'Product Type':['CV Boots Kit'],
    
    'Vendor Notes':['* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500712'],   
    'MPN':['AT-03079'],
    'SKU':['120803'],
    
    'FRONT/REAR':['REAR'],
    'INBOARD/OUTBOARD':['OUTBOARD']
}
list_models = [
    
'Outlander Max 400 EFI XT',
'Outlander Max 500 HO EFI LTD',
'Outlander Max 500 EFI XT',
'Outlander Max 500 EFI DPS',
'Outlander Max 500 HO EFI XT',
'Outlander Max 500 HO EFI XT-P',
'Outlander 500 HO 4x4 EFI',
'Outlander 500 HO 4x4 EFI XT',
'Outlander 500 HO 4x4 EFI XT-P',
'Outlander 500 EFI XT',
'Outlander 500 EFI',
'Outlander 500 EFI DPS',
'Outlander Max 400 EFI',
'Outlander Max 500 EFI',
'Renegade 500',
'Outlander 570 DPS',
'Outlander 570 XT',
'Outlander 570',
'Outlander 570 X mr',
'Outlander Max 570 DPS',
'Outlander Max 570 XT',
'Outlander Max 570',
'Renegade 570',
'Renegade 570 X mr',
'Outlander 650 HO 4x4 EFI',
'Outlander 650 HO 4x4 EFI XT',
'Outlander 650 EFI XT-P',
'Outlander 650 EFI XT',
'Outlander 650 EFI',
'Outlander 650 EFI DPS',
'Outlander 650 X mr',
'Outlander Max 650 HO EFI',
'Outlander Max 650 HO EFI XT',
'Outlander Max 650 EFI XT-P',
'Outlander Max 650 EFI XT',
'Outlander Max 650 EFI',
'Outlander Max 650 EFI DPS',
'Outlander Max 650 DPS',
'Outlander Max 650 XT',
'Outlander Max 650 6X6 DPS',
'Outlander 650 DPS',
'Outlander 650 XT',
'Outlander 650',
'Outlander 800R EFI X mr',
'Renegade 800',
'Renegade 800 X',
'Renegade 800 Backcountry',
'Renegade 800 Adrenaline',
'Renegade 800 Backcountry X',
'Renegade 800R',
'Renegade 800R X xc',
'Outlander 850 DPS',
'Outlander 850 XT',
'Outlander 850 XT-P',
'Outlander 850 X mr',
'Outlander 850 North Edition',
'Outlander 850',
'Outlander Max 850 XT-P',
'Outlander Max 850 XT',
'Renegade 850 X xc',
'Renegade 850',
'Outlander 1000 EFI DPS',
'Outlander 1000 EFI XT',
'Outlander 1000 EFI XT-P',
'Outlander 1000 X mr',
'Outlander 1000 6x6 XT',
'Outlander 1000 DPS',
'Outlander 1000 XT',
'Outlander 1000 XT-P',
'Outlander 1000 X xc',
'Outlander Max 1000 EFI DPS',
'Outlander Max 1000 EFI XT',
'Outlander Max 1000 EFI XT-P',
'Outlander Max 1000 EFI LTD',
'Outlander Max 1000 XT',
'Outlander Max 1000 XT-P',
'Outlander Max 1000 Limited',
'Outlander Max 1000 6X6 XT',
'Renegade 1000',
'Renegade 1000 X xc',
'Renegade 1000 X mr',
'Renegade 1000R X xc',
'Defender HD5',
'Defender HD5 DPS',
'Commander 800R',
'Commander 800R XT',
'Commander 800R DPS',
'Commander Max 800R DPS',
'Defender HD8',
'Defender HD8 DPS',
'Defender HD8 XT',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Defender HD8 XT CAB',
'Defender MAX HD8',
'Defender HD8 DPS CAB',
'Maverick Trail 800',
'Maverick Trail 800 DPS',
'Commander 1000 X',
'Commander 1000 XT',
'Commander 1000',
'Commander 1000 Limited',
'Commander 1000 DPS',
'Commander 1000 XT-P',
'Commander 1000R Limited',
'Commander 1000R DPS',
'Commander 1000R XT',
'Commander 1000R XT-P',
'Commander 1000R X mr',
'Commander Max 1000 XT',
'Commander Max 1000 DPS',
'Commander Max 1000 Limited',
'Commander Max 1000R Limited',
'Commander Max 1000R DPS',
'Commander Max 1000R XT',
'Commander Max 1000R XT-P',
'Defender HD10',
'Defender HD10 DPS',
'Defender HD10 XT',
'Defender HD10 XT CAB',
'Defender MAX HD10 DPS',
'Defender MAX HD10 XT',
'Defender MAX HD10 XT CAB',
'Defender HD10 XT-P',
'Defender HD10 X mr',
'Defender MAX HD10 X mr',
'Defender HD10 6X6 DPS',
'Defender PRO HD10',
'Defender PRO HD10 XT',
'Defender HD10 Limited',
'Defender MAX HD10 Limited',
'Defender HD10 6X6 XT',
'Defender PRO HD10 Limited',
'Maverick 1000R',
'Maverick 1000R X rs',
'Maverick 1000R X rs DPS',
'Maverick 1000R X xc DPS',
'Maverick 1000R X mr DPS',
'Maverick 1000R X ds',
'Maverick 1000R Turbo X ds',
'Maverick 1000R XC',
'Maverick 1000R Turbo X rs',
'Maverick 1000R DPS',
'Maverick 1000R xc DPS',
'Maverick 1000R X xc',
'Maverick 1000R Turbo',
'Maverick 1000R X mr',
'Maverick Max 1000R',
'Maverick Max 1000R X rs DPS',
'Maverick Max 1000R X ds',
'Maverick Max 1000R Turbo X ds',
'Maverick Max 1000R DPS',
'Maverick Max 1000R Turbo X rs',
'Maverick Max 1000R Turbo',
'Maverick Max 1000R X mr',
'Sportsman 500 EFI Touring',
'Sportsman 500 EFI X2',
'Sportsman 500 EFI',
'Sportsman 500 HO',
'Sportsman 500 HO Touring',
'Sportsman 550 EFI XP',
'Sportsman 550 EFI XP w/ EPS',
'Sportsman 700 EFI X2',
'Sportsman 800 EFI HO',
'Sportsman 800 EFI Touring',
'Sportsman 800 EFI X2',
'Sportsman 800 EFI 6x6 Big Boss',
'Sportsman 800 EFI',
'Sportsman 800 6x6 Big Boss',
'Sportsman 850 EFI XP',
'Sportsman 850 EFI XP w/ EPS',
'Sportsman 850 HO XP EPS Browning LE',
'Sportsman 850 HO XP EPS',
'Sportsman 850 HO XP EPS Orange Madness LE',
'Sportsman 850 HO XP',
'Sportsman 850 HO XP EPS Stealth Black LE',
'Sportsman 850 HO XP EPS Pearl White LE',
'Ranger 700 Crew',
'Ranger 6x6 700 EFI',
'Ranger HD 700',
'Ranger RZR 800 S',
'Ranger 800 Crew',
'Ranger 6x6 800',
'Ranger RZR 4 800 Gordon Edition',
'Ranger RZR 4 800 EPS Robby Gordon',
'Ranger MVRS 700 4x4',
'Ranger MVRS 700 6x6',
'Ranger MVRS 800 6x6',
'Ranger MVRS 800 4x4',
'Ranger RZR 4 800 EPS Robby Gordon LE',
'Ranger RZR 800 S LE',
'Ranger RZR 4 800',
'Ranger RZR 4 800 EPS LE',
'Ranger RZR S 800 EPS LE',

]

years = list(range(2008, 2024))

def generate_df(model, data, year):
    data_copy = data.copy()
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

dfs=[]
for year in years:
    df1 = pd.concat([generate_df(model, boots, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

final_df = pd.concat(dfs, ignore_index = True)
                     
final_df
# Out:
#           Make                                 Model Vendor  \
# 0     Kawasaki              Outlander Max 400 EFI XT   NACH
# 1     Kawasaki          Outlander Max 500 HO EFI LTD   NACH
# 2     Kawasaki              Outlander Max 500 EFI XT   NACH
# 3     Kawasaki             Outlander Max 500 EFI DPS   NACH
# 4     Kawasaki           Outlander Max 500 HO EFI XT   NACH
# ...        ...                                   ...    ...
# 3099  Kawasaki  Ranger RZR 4 800 EPS Robby Gordon LE   NACH
# 3100  Kawasaki                   Ranger RZR 800 S LE   NACH
# 3101  Kawasaki                      Ranger RZR 4 800   NACH
# 3102  Kawasaki               Ranger RZR 4 800 EPS LE   NACH
# 3103  Kawasaki               Ranger RZR S 800 EPS LE   NACH
#
#                         Vendor Code  Product Type  \
# 0     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03079REAR-OUTBOARD.CSV"
final_df.to_csv(file_path, index = False)

# %%
#Test OOP
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': self.make,
            'Model': self.model,
            'Vendor': self.vendor,
            'Vendor Code': self.vendor_code,
            'Product Type': self.product_type,
            'Vendor Notes': self.vendor_notes,
            'MPN': self.mpn,
            'SKU': self.sku,
            'FRONT/REAR': self.front_rear,
            'INBOARD/OUTBOARD': self.inboard_outboard
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = model
        boot_data['Year'] = year
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500712',
    mpn='AT-03078',
    sku='120824',
    front_rear='REAR',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = ['KRF750 Teryx 4x4']
years = list(range(2008, 2012))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 70
#      68 # Generate the DataFrame using OOP
#      69 generator = BootGenerator(boot_template, list_models, years)
# ---> 70 final_df = generator.generate_boots()
#      72 # Display the final DataFrame
#      73 final_df
#
# Cell In[5], line 40, in BootGenerator.generate_boots(self)
#      38 dfs = []
#      39 for year in self.years:
# ---> 40     df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
#      41     dfs.append(df_year)
#      42 return pd.concat(dfs, ignore_index=True)
#
# Cell In[5], line 40, in <listcomp>(.0)
#      38 dfs = []
#      39 for year in self.years:
# ---> 40     df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
#      41     dfs.append(df_year)
# ...

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500712',
    mpn='AT-03078',
    sku='120824',
    front_rear='REAR',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = ['KRF750 Teryx 4x4',
              'test2']
years = list(range(2008, 2012))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#        Make             Model Vendor                    Vendor Code  \
# 0  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  Kawasaki             test2   NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  Kawasaki             test2   NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 5  Kawasaki             test2   NACH  NACHMAN INTERNATIONAL CO. LTD
# 6  Kawasaki  KRF750 Teryx 4x4   NACH  NACHMAN INTERNATIONAL CO. LTD
# 7  Kawasaki             test2   NACH  NACHMAN INTERNATIONAL CO. LTD
#
#    Product Type                                       Vendor Notes       MPN  \
# 0  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 1  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# 2  CV Boots Kit  * OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR ...  AT-03078
# ...

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

    def save_to_csv(self, file_path):
        final_df = self.generate_boots()
        final_df.to_csv(file_path, index=False)
        print(f"Data saved to {file_path}")

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; FROM SERIAL # 9B500712',
    mpn='AT-03078',
    sku='120824',
    front_rear='REAR',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = ['KRF750 Teryx 4x4', 'test2']
years = list(range(2008, 2012))

# Generate the DataFrame and save to CSV using OOP
generator = BootGenerator(boot_template, list_models, years)
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\testing lang.CSV"
generator.save_to_csv(file_path)
# Out:
# Data saved to C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\testing lang.CSV

# %%
import pandas as pd

class Boot1:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard
        
    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }
class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years
        
    def generate_boots(self):
        dfs=[]
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)
    
    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model],
        boot_data['Year'] = [year],
        return pd.DataFrame(boot_data)
            
    def save_to_csv(self, file_path):
        final_df = self.generate_boots()
        final_df.to_csv(file_path, index=False)
        print(f"Data saved to {file_path}")

# Initialize the boot template
boot_template = Boot1(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.',
    mpn='AT-03079',
    sku='120803',
    front_rear='REAR',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = [
    'Outlander Max 400 EFI XT',
'Outlander Max 500 HO EFI LTD',
'Outlander Max 500 HO EFI XT-P',
'Outlander Max 500 HO EFI',
'Outlander Max 500 HO EFI XT',
'Outlander Max 500 EFI',
'Outlander Max 500 EFI DPS',
'Outlander Max 500 EFI XT',
'Outlander 500 HO 4x4 EFI',
'Outlander 500 HO 4x4 EFI XT',
'Outlander 500 HO 4x4 EFI XT-P',
'Outlander 500 EFI XT',
'Outlander 500 EFI',
'Renegade 500',
'Outlander 570 XT',
'Outlander 570 DPS',
'Outlander 570',
'Outlander 570 mr',
'Outlander 570 X mr',
'Outlander L 570 X mr',
'Outlander Max 570 DPS',
'Outlander Max 570 XT',
'Outlander Max 570',
'Renegade 570',
'Renegade 570 X mr',
'Outlander 650 HO 4x4 EFI',
'Outlander 650 HO 4x4 EFI XT',
'Outlander 650 EFI XT-P',
'Outlander 650 EFI XT',
'Outlander 650 EFI',
'Outlander 650 EFI DPS',
'Outlander 650 X mr',
'Outlander 650 6x6 XT',
'Outlander 650',
'Outlander 650 DPS',
'Outlander 650 XT',
'Outlander 650 6x6 DPS',
'Outlander Max 650 EFI',
'Outlander Max 650 EFI DPS',
'Outlander Max 650 EFI XT',
'Outlander Max 650 DPS',
'Outlander Max 650 XT',
'Outlander Max 650 North Edition',
'Outlander Max 650 6X6 DPS',
'Renegade 800',
'Renegade 800 X',
'Renegade 800R',
'Renegade 800R X xc',
'Outlander 850 X mr',
'Outlander 850 DPS',
'Outlander 850 XT',
'Outlander 850 XT-P',
'Outlander 850 North Edition',
'Outlander 850',
'Outlander Max 850 XT-P',
'Outlander Max 850 XT',
'Renegade 850',
'Renegade 850 X xc',
'Outlander 1000 EFI XT',
'Outlander 1000 EFI',
'Outlander 1000 EFI DPS',
'Outlander 1000 EFI XT-P',
'Outlander 1000 X mr',
'Outlander 1000 6x6 XT',
'Outlander 1000 DPS',
'Outlander 1000 XT',
'Outlander 1000 XT-P',
'Outlander 1000 X xc',
'Outlander Max 1000 EFI DPS',
'Outlander Max 1000 EFI XT',
'Outlander Max 1000 EFI XT-P',
'Outlander Max 1000 EFI LTD',
'Outlander Max 1000 XT',
'Outlander Max 1000 XT-P',
'Outlander Max 1000 Limited',
'Outlander Max 1000 6X6 XT',
'Renegade 1000 EFI X xc',
'Renegade 1000',
'Renegade 1000 X xc',
'Renegade 1000 X mr',
'Renegade 1000R X xc',
'Defender HD5',
'Defender HD5 DPS',
'Commander 800R XT',
'Commander 800R',
'Commander 800R DPS',
'Commander Max 800R DPS',
'Defender HD8',
'Defender HD8 DPS',
'Defender HD8 XT',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Defender HD8 XT CAB',
'Defender MAX HD8',
'Defender HD8 DPS CAB',
'Maverick Trail 800',
'Maverick Trail 800 DPS',
'Commander 1000 X',
'Commander 1000 XT',
'Commander 1000',
'Commander 1000 Limited',
'Commander 1000 DPS',
'Commander 1000 XT-P',
'Commander 1000R Limited',
'Commander 1000R DPS',
'Commander 1000R XT',
'Commander 1000R XT-P',
'Commander 1000R X mr',
'Commander Max 1000 XT',
'Commander Max 1000 DPS',
'Commander Max 1000 Limited',
'Commander Max 1000R Limited',
'Commander Max 1000R DPS',
'Commander Max 1000R XT',
'Commander Max 1000R XT-P',
'Defender HD10',
'Defender HD10 DPS',
'Defender HD10 XT',
'Defender HD10 XT CAB',
'Defender MAX HD10 DPS',
'Defender MAX HD10 XT',
'Defender MAX HD10 XT CAB',
'Defender HD10 XT-P',
'Defender MAX HD10 Lone Star',
'Defender HD10 X mr',
'Defender MAX HD10 X mr',
'Defender HD10 6X6 DPS',
'Defender PRO HD10',
'Defender PRO HD10 XT',
'Defender HD10 Limited',
'Defender MAX HD10 Limited',
'Defender HD10 6X6 XT',
'Defender PRO HD10 Limited',
'Defender PRO HD10 Lone Star',

]
years = list(range(2008, 2024))

# Generate the DataFrame and save to CSV using OOP
generator = BootGenerator(boot_template, list_models, years)
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-3079.CSV"
generator.save_to_csv(file_path)
# Out:
# Data saved to C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-3079.CSV

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; ALL YEAR 2008 : Outlander XT 650, Renegade 4x4 500, Outlander/max 500 are (REAR W/10MM BANDS); ALL year 2015: 800 Commander STD/DPS/XT 4X4  (BUILT NOV 2014 AND AFTER) and 800 Commander STD/DPS/XT 4X4  (BUILT NOV 2014 AND AFTER)',
    mpn='AT-03079',
    sku='120803',
    front_rear='REAR',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = [
'Outlander Max 400 EFI XT',
'Outlander Max 500 HO EFI LTD',
'Outlander Max 500 HO EFI XT-P',
'Outlander Max 500 HO EFI',
'Outlander Max 500 HO EFI XT',
'Outlander Max 500 EFI',
'Outlander Max 500 EFI DPS',
'Outlander Max 500 EFI XT',
'Outlander 500 HO 4x4 EFI',
'Outlander 500 HO 4x4 EFI XT',
'Outlander 500 HO 4x4 EFI XT-P',
'Outlander 500 EFI XT',
'Outlander 500 EFI',
'Renegade 500',
'Outlander 570 XT',
'Outlander 570 DPS',
'Outlander 570',
'Outlander 570 mr',
'Outlander 570 X mr',
'Outlander L 570 X mr',
'Outlander Max 570 DPS',
'Outlander Max 570 XT',
'Outlander Max 570',
'Renegade 570',
'Renegade 570 X mr',
'Outlander 650 HO 4x4 EFI',
'Outlander 650 HO 4x4 EFI XT',
'Outlander 650 EFI XT-P',
'Outlander 650 EFI XT',
'Outlander 650 EFI',
'Outlander 650 EFI DPS',
'Outlander 650 X mr',
'Outlander 650 6x6 XT',
'Outlander 650',
'Outlander 650 DPS',
'Outlander 650 XT',
'Outlander 650 6x6 DPS',
'Outlander Max 650 EFI',
'Outlander Max 650 EFI DPS',
'Outlander Max 650 EFI XT',
'Outlander Max 650 DPS',
'Outlander Max 650 XT',
'Outlander Max 650 North Edition',
'Outlander Max 650 6X6 DPS',
'Renegade 800',
'Renegade 800 X',
'Renegade 800R',
'Renegade 800R X xc',
'Outlander 850 X mr',
'Outlander 850 DPS',
'Outlander 850 XT',
'Outlander 850 XT-P',
'Outlander 850 North Edition',
'Outlander 850',
'Outlander Max 850 XT-P',
'Outlander Max 850 XT',
'Renegade 850',
'Renegade 850 X xc',
'Outlander 1000 EFI XT',
'Outlander 1000 EFI',
'Outlander 1000 EFI DPS',
'Outlander 1000 EFI XT-P',
'Outlander 1000 X mr',
'Outlander 1000 6x6 XT',
'Outlander 1000 DPS',
'Outlander 1000 XT',
'Outlander 1000 XT-P',
'Outlander 1000 X xc',
'Outlander Max 1000 EFI DPS',
'Outlander Max 1000 EFI XT',
'Outlander Max 1000 EFI XT-P',
'Outlander Max 1000 EFI LTD',
'Outlander Max 1000 XT',
'Outlander Max 1000 XT-P',
'Outlander Max 1000 Limited',
'Outlander Max 1000 6X6 XT',
'Renegade 1000 EFI X xc',
'Renegade 1000',
'Renegade 1000 X xc',
'Renegade 1000 X mr',
'Renegade 1000R X xc',
'Defender HD5',
'Defender HD5 DPS',
'Commander 800R XT',
'Commander 800R',
'Commander 800R DPS',
'Commander Max 800R DPS',
'Defender HD8',
'Defender HD8 DPS',
'Defender HD8 XT',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Defender HD8 XT CAB',
'Defender MAX HD8',
'Defender HD8 DPS CAB',
'Maverick Trail 800',
'Maverick Trail 800 DPS',
'Commander 1000 X',
'Commander 1000 XT',
'Commander 1000',
'Commander 1000 Limited',
'Commander 1000 DPS',
'Commander 1000 XT-P',
'Commander 1000R Limited',
'Commander 1000R DPS',
'Commander 1000R XT',
'Commander 1000R XT-P',
'Commander 1000R X mr',
'Commander Max 1000 XT',
'Commander Max 1000 DPS',
'Commander Max 1000 Limited',
'Commander Max 1000R Limited',
'Commander Max 1000R DPS',
'Commander Max 1000R XT',
'Commander Max 1000R XT-P',
'Defender HD10',
'Defender HD10 DPS',
'Defender HD10 XT',
'Defender HD10 XT CAB',
'Defender MAX HD10 DPS',
'Defender MAX HD10 XT',
'Defender MAX HD10 XT CAB',
'Defender HD10 XT-P',
'Defender MAX HD10 Lone Star',
'Defender HD10 X mr',
'Defender MAX HD10 X mr',
'Defender HD10 6X6 DPS',
'Defender PRO HD10',
'Defender PRO HD10 XT',
'Defender HD10 Limited',
'Defender MAX HD10 Limited',
'Defender HD10 6X6 XT',
'Defender PRO HD10 Limited',
'Defender PRO HD10 Lone Star',

]
years = list(range(2008, 2024))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#           Make                          Model Vendor  \
# 0     Kawasaki       Outlander Max 400 EFI XT   NACH
# 1     Kawasaki   Outlander Max 500 HO EFI LTD   NACH
# 2     Kawasaki  Outlander Max 500 HO EFI XT-P   NACH
# 3     Kawasaki       Outlander Max 500 HO EFI   NACH
# 4     Kawasaki    Outlander Max 500 HO EFI XT   NACH
# ...        ...                            ...    ...
# 2139  Kawasaki          Defender HD10 Limited   NACH
# 2140  Kawasaki      Defender MAX HD10 Limited   NACH
# 2141  Kawasaki           Defender HD10 6X6 XT   NACH
# 2142  Kawasaki      Defender PRO HD10 Limited   NACH
# 2143  Kawasaki    Defender PRO HD10 Lone Star   NACH
#
#                         Vendor Code  Product Type  \
# 0     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 3     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 4     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03079-INBOARD(copy).csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; ALL YEAR 2008 : Outlander XT 650, Renegade 4x4 500, Outlander/max 500 are (REAR W/10MM BANDS); ALL year 2015: 800 Commander STD/DPS/XT 4X4  (BUILT NOV 2014 AND AFTER) and 800 Commander STD/DPS/XT 4X4  (BUILT NOV 2014 AND AFTER)',
    mpn='AT-03079',
    sku='120803',
    front_rear='REAR',
    inboard_outboard='OUTBOARD'
)

# List of models and years
list_models = [
'Outlander Max 400 EFI XT',
'Outlander Max 500 HO EFI LTD',
'Outlander Max 500 HO EFI XT-P',
'Outlander Max 500 HO EFI',
'Outlander Max 500 HO EFI XT',
'Outlander Max 500 EFI',
'Outlander Max 500 EFI DPS',
'Outlander Max 500 EFI XT',
'Outlander 500 HO 4x4 EFI',
'Outlander 500 HO 4x4 EFI XT',
'Outlander 500 HO 4x4 EFI XT-P',
'Outlander 500 EFI XT',
'Outlander 500 EFI',
'Renegade 500',
'Outlander 570 XT',
'Outlander 570 DPS',
'Outlander 570',
'Outlander 570 mr',
'Outlander 570 X mr',
'Outlander L 570 X mr',
'Outlander Max 570 DPS',
'Outlander Max 570 XT',
'Outlander Max 570',
'Renegade 570',
'Renegade 570 X mr',
'Outlander 650 HO 4x4 EFI',
'Outlander 650 HO 4x4 EFI XT',
'Outlander 650 EFI XT-P',
'Outlander 650 EFI XT',
'Outlander 650 EFI',
'Outlander 650 EFI DPS',
'Outlander 650 X mr',
'Outlander 650 6x6 XT',
'Outlander 650',
'Outlander 650 DPS',
'Outlander 650 XT',
'Outlander 650 6x6 DPS',
'Outlander Max 650 EFI',
'Outlander Max 650 EFI DPS',
'Outlander Max 650 EFI XT',
'Outlander Max 650 DPS',
'Outlander Max 650 XT',
'Outlander Max 650 North Edition',
'Outlander Max 650 6X6 DPS',
'Renegade 800',
'Renegade 800 X',
'Renegade 800R',
'Renegade 800R X xc',
'Outlander 850 X mr',
'Outlander 850 DPS',
'Outlander 850 XT',
'Outlander 850 XT-P',
'Outlander 850 North Edition',
'Outlander 850',
'Outlander Max 850 XT-P',
'Outlander Max 850 XT',
'Renegade 850',
'Renegade 850 X xc',
'Outlander 1000 EFI XT',
'Outlander 1000 EFI',
'Outlander 1000 EFI DPS',
'Outlander 1000 EFI XT-P',
'Outlander 1000 X mr',
'Outlander 1000 6x6 XT',
'Outlander 1000 DPS',
'Outlander 1000 XT',
'Outlander 1000 XT-P',
'Outlander 1000 X xc',
'Outlander Max 1000 EFI DPS',
'Outlander Max 1000 EFI XT',
'Outlander Max 1000 EFI XT-P',
'Outlander Max 1000 EFI LTD',
'Outlander Max 1000 XT',
'Outlander Max 1000 XT-P',
'Outlander Max 1000 Limited',
'Outlander Max 1000 6X6 XT',
'Renegade 1000 EFI X xc',
'Renegade 1000',
'Renegade 1000 X xc',
'Renegade 1000 X mr',
'Renegade 1000R X xc',
'Defender HD5',
'Defender HD5 DPS',
'Commander 800R XT',
'Commander 800R',
'Commander 800R DPS',
'Commander Max 800R DPS',
'Defender HD8',
'Defender HD8 DPS',
'Defender HD8 XT',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Defender HD8 XT CAB',
'Defender MAX HD8',
'Defender HD8 DPS CAB',
'Maverick Trail 800',
'Maverick Trail 800 DPS',
'Commander 1000 X',
'Commander 1000 XT',
'Commander 1000',
'Commander 1000 Limited',
'Commander 1000 DPS',
'Commander 1000 XT-P',
'Commander 1000R Limited',
'Commander 1000R DPS',
'Commander 1000R XT',
'Commander 1000R XT-P',
'Commander 1000R X mr',
'Commander Max 1000 XT',
'Commander Max 1000 DPS',
'Commander Max 1000 Limited',
'Commander Max 1000R Limited',
'Commander Max 1000R DPS',
'Commander Max 1000R XT',
'Commander Max 1000R XT-P',
'Defender HD10',
'Defender HD10 DPS',
'Defender HD10 XT',
'Defender HD10 XT CAB',
'Defender MAX HD10 DPS',
'Defender MAX HD10 XT',
'Defender MAX HD10 XT CAB',
'Defender HD10 XT-P',
'Defender MAX HD10 Lone Star',
'Defender HD10 X mr',
'Defender MAX HD10 X mr',
'Defender HD10 6X6 DPS',
'Defender PRO HD10',
'Defender PRO HD10 XT',
'Defender HD10 Limited',
'Defender MAX HD10 Limited',
'Defender HD10 6X6 XT',
'Defender PRO HD10 Limited',
'Defender PRO HD10 Lone Star',

]
years = list(range(2008, 2024))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#           Make                          Model Vendor  \
# 0     Kawasaki       Outlander Max 400 EFI XT   NACH
# 1     Kawasaki   Outlander Max 500 HO EFI LTD   NACH
# 2     Kawasaki  Outlander Max 500 HO EFI XT-P   NACH
# 3     Kawasaki       Outlander Max 500 HO EFI   NACH
# 4     Kawasaki    Outlander Max 500 HO EFI XT   NACH
# ...        ...                            ...    ...
# 2139  Kawasaki          Defender HD10 Limited   NACH
# 2140  Kawasaki      Defender MAX HD10 Limited   NACH
# 2141  Kawasaki           Defender HD10 6X6 XT   NACH
# 2142  Kawasaki      Defender PRO HD10 Limited   NACH
# 2143  Kawasaki    Defender PRO HD10 Lone Star   NACH
#
#                         Vendor Code  Product Type  \
# 0     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 3     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 4     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03079RearOUTBOARD.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.   ',
    mpn='AT-03080',
    sku='121804',
    front_rear='FRONT',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = [
'Maverick X3 900 HO',
'Maverick X3 DS Turbo',
'Maverick X3 DS Turbo R',
'Maverick X3 DS Turbo RR',
'Maverick X3 Max DS Turbo',
'Maverick X3 Max DS Turbo R',
'Maverick X3 Max DS Turbo RR',
'Maverick X3 Max RS Turbo',
'Maverick X3 Max RS Turbo R',
'Maverick X3 Max RS Turbo RR',
'Maverick X3 Max Turbo',
'Maverick X3 Max Turbo R',
'Maverick X3 Max X ds Turbo R',
'Maverick X3 Max X ds Turbo RR',
'Maverick X3 Max X mr Turbo RR',
'Maverick X3 Max X rc Turbo RR',
'Maverick X3 Max X rs Turbo R',
'Maverick X3 Max X rs Turbo RR',
'Maverick X3 RS Turbo',
'Maverick X3 RS Turbo R',
'Maverick X3 RS Turbo RR',
'Maverick X3 Turbo',
'Maverick X3 Turbo R',
'Maverick X3 X ds Turbo R',
'Maverick X3 X ds Turbo RR',
'Maverick X3 X mr Turbo',
'Maverick X3 X mr Turbo R',
'Maverick X3 X mr Turbo RR',
'Maverick X3 X mr Turbo RR 64',
'Maverick X3 X mr Turbo RR 72',
'Maverick X3 X rc Turbo',
'Maverick X3 X rc Turbo R',
'Maverick X3 X rc Turbo RR',
'Maverick X3 X rc Turbo RR 64',
'Maverick X3 X rc Turbo RR 72',
'Maverick X3 X rs Turbo R',
'Maverick X3 X rs Turbo RR',
'Commander 1000',
'Commander 1000 DPS',
'Commander 1000 Limited',
'Commander 1000 X',
'Commander 1000 XT',
'Commander 1000 XT-P',
'Commander 1000R DPS',
'Commander 1000R Limited',
'Commander 1000R XT',
'Commander 1000R XT-P',
'Maverick 1000R',
'Maverick 1000R DPS',
'Maverick 1000R Turbo',
'Maverick 1000R Turbo X ds',
'Maverick 1000R Turbo X rs',
'Maverick 1000R X ds',
'Maverick 1000R X mr',
'Maverick 1000R X mr DPS',
'Maverick 1000R X rs',
'Maverick 1000R X rs DPS',
'Maverick 1000R X xc',
'Maverick 1000R X xc DPS',
'Maverick 1000R XC',
'Maverick 1000R xc DPS',


]
years = list(range(2013, 2022))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#          Make                     Model Vendor                    Vendor Code  \
# 0    Kawasaki        Maverick X3 900 HO   NACH  NACHMAN INTERNATIONAL CO. LTD
# 1    Kawasaki      Maverick X3 DS Turbo   NACH  NACHMAN INTERNATIONAL CO. LTD
# 2    Kawasaki    Maverick X3 DS Turbo R   NACH  NACHMAN INTERNATIONAL CO. LTD
# 3    Kawasaki   Maverick X3 DS Turbo RR   NACH  NACHMAN INTERNATIONAL CO. LTD
# 4    Kawasaki  Maverick X3 Max DS Turbo   NACH  NACHMAN INTERNATIONAL CO. LTD
# ..        ...                       ...    ...                            ...
# 544  Kawasaki   Maverick 1000R X rs DPS   NACH  NACHMAN INTERNATIONAL CO. LTD
# 545  Kawasaki       Maverick 1000R X xc   NACH  NACHMAN INTERNATIONAL CO. LTD
# 546  Kawasaki   Maverick 1000R X xc DPS   NACH  NACHMAN INTERNATIONAL CO. LTD
# 547  Kawasaki         Maverick 1000R XC   NACH  NACHMAN INTERNATIONAL CO. LTD
# 548  Kawasaki     Maverick 1000R xc DPS   NACH  NACHMAN INTERNATIONAL CO. LTD
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03080FrontInboard.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.; All 2015: 1000 COMMANDER DPS/XT/XT-P/LTD (BUILT OCT 2014 AND BEFORE) and 1000 COMMANDER MAX DPS/XT/LTD (BUILT OCT 2014 AND BEFORE); All 2017-18: 1000 MAVERICK MAX XMR (NON TURBO); All 2019-21: 1000 MAVERICK SPORT R DPS (100HP)', 
    mpn='AT-03080',
    sku='121804',
    front_rear='FRONT',
    inboard_outboard='OUTBOARD'
)

# List of models and years
list_models = [
'Renegade 570',
'Renegade 570 X mr',
'Outlander 650 X mr',
'Outlander 800R EFI X mr',
'Outlander 850 X mr',
'Outlander 1000 X mr',
'Outlander 570 X mr',
'Maverick 1000R X mr',
'Maverick 1000R X mr DPS',
'Maverick Max 1000R X mr',
'Maverick Sport 1000R X mr',
'Maverick X3 Max X mr Turbo RR',
'Maverick X3 X mr Turbo',
'Maverick X3 X mr Turbo R',
'Maverick X3 X mr Turbo RR',
'Commander 1000',
'Commander 1000 DPS',
'Commander 1000 Limited',
'Commander 1000 X',
'Commander 1000 XT',
'Commander 1000 XT-P',
'Commander 1000R DPS',
'Commander 1000R Limited',
'Commander 1000R XT',
'Commander 1000R XT-P',
'Hawkeye 2x4',
'Sportsman 400 HO',
'Scrambler 500 4x4',
'Sportsman 500 HO',
'Sportsman 500 HO Polaris Pursuite LE',
'Sportsman 500 HO Touring',
'Sportsman 800 6x6 Big Boss',
'Sportsman 800 EFI',
'Scrambler 850',
'Scrambler 1000 XP',
'Sportsman 1000 XP',
'Sportsman 1000 XP High Lifter Edition',
'Sportsman 1000 XP Hunter Edition',
'Sportsman 1000 Touring XP',
'Sportsman 1000 Touring XP Limited',
'RZR XP 1000 EPS',
'RZR XP 1000 EPS Gold Matte Metallic LE',
'RZR XP 1000 EPS High Lifter Edition',
'RZR XP 1000 EPS Velocity Blue LE',
'RZR XP 4 1000 EPS',
'RZR XP 4 1000 EPS High Lifter Edition',
'RZR XP 4 Turbo EPS',
'RZR XP Turbo EPS',
'Ranger RZR XP 4 900',
'Ranger RZR XP 4 900 EPS LE',
'Ranger RZR XP 900',
'Ranger RZR XP 900 EPS LE',
'Ranger RZR XP 900 EPS Walker Evans LE',
'Ranger RZR XP 900 HO Jagged X Edition'



]
years = list(range(2011, 2022))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#          Make                                  Model Vendor  \
# 0    Kawasaki                           Renegade 570   NACH
# 1    Kawasaki                      Renegade 570 X mr   NACH
# 2    Kawasaki                     Outlander 650 X mr   NACH
# 3    Kawasaki                Outlander 800R EFI X mr   NACH
# 4    Kawasaki                     Outlander 850 X mr   NACH
# ..        ...                                    ...    ...
# 589  Kawasaki             Ranger RZR XP 4 900 EPS LE   NACH
# 590  Kawasaki                      Ranger RZR XP 900   NACH
# 591  Kawasaki               Ranger RZR XP 900 EPS LE   NACH
# 592  Kawasaki  Ranger RZR XP 900 EPS Walker Evans LE   NACH
# 593  Kawasaki  Ranger RZR XP 900 HO Jagged X Edition   NACH
#
#                        Vendor Code  Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03080FrontOutboard.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.   ', 
    mpn='AT-03080',
    sku='121804',
    front_rear='REAR',
    inboard_outboard='OUTBOARD'
)

# List of models and years
list_models = [
    
'Scrambler 500 4x4',
'Sportsman 500 HO',
'Sportsman 500 HO Polaris Pursuite LE',
'Sportsman 500 HO Touring',
'Ranger 570 EPS',
'Ranger 570 EPS Full-Size',
'Ranger 570 EPS Hunter Edition',
'Ranger 570 EPS LE',
'Ranger 570 Full-Size',
'Ranger XP 570 EPS',
'RZR S 570 EPS',
'Ranger 570 Crew',
'Ranger 570 Crew EPS',
'Ranger 570 Crew EPS Full-Size',
'Ranger 570 Crew EPS LE',
'Ranger 570 Crew Full-Size',
'Ranger 800 Crew',
'Ranger 800 Crew EPS',
'Ranger 800 Crew EPS LE',
'Ranger 800 EFI',
'Ranger 800 EFI EPS',
'Ranger 800 EFI EPS LE',
'Ranger 800 EFI LE',
'Ranger 800 EFI Mid-Size',
'Ranger 800 EFI Mid-Size LE',
'Ranger 800 EPS Mid-Size LE',
'Ranger 800 HD',
'Ranger 800 HD EPS',
'Ranger 800 XP',
'Ranger 800 XP EPS',
'Ranger 800 XP EPS LE',
'Ranger 800 XP LE',
'Ranger RZR 800',
'Ranger RZR 800 EPS',
'Ranger RZR 800 EPS LE',
'Ranger RZR 800 LE',
'Ranger RZR 800 S',
'Ranger RZR 800 S LE',
'Ranger RZR 800 SW Military',
'RZR 800',
'RZR 800 EPS LE',
'RZR 800 XC Edition',
'Ranger RZR 4 800',
'Ranger RZR 4 800 EPS LE',
'Ranger RZR 4 800 EPS Robby Gordon',
'Ranger RZR 4 800 EPS Robby Gordon LE',
'Ranger RZR 4 800 Gordon Edition',
'RZR 4 800 EPS LE',
'ACE 900 XC',
'Ranger 900-6 Crew',
'Ranger 900-6 Crew EPS',
'Ranger 900 Crew',
'Ranger 900 Crew EPS',
'Ranger 900 Crew EPS LE',
'Ranger 900 XP',
'Ranger 900 XP Bronze Mist LE',
'Ranger 900 XP Deluxe',
'Ranger 900 XP EPS',
'Ranger 900 XP EPS Browning LE',
'Ranger 900 XP EPS Deluxe',
'Ranger 900 XP EPS Hunter Deluxe Edition',
'Ranger 900 XP EPS Hunter Edition',
'Ranger 900 XP EPS LE',
'Ranger 900 XP EPS Northstar Edition',
'Ranger 900 XP LE',
'Ranger RZR XP 4 900',
'Ranger RZR XP 4 900 EPS LE',
'Ranger RZR XP 900',
'Ranger RZR XP 900 EPS LE',
'Ranger RZR XP 900 EPS Walker Evans LE',
'Ranger RZR XP 900 HO Jagged X Edition',
'Ranger RZR XP 900 LE',
'RZR XP 1000 EPS',
'RZR XP 1000 EPS Desert Edition',
'RZR XP 1000 EPS Fox Edition',
'RZR XP 1000 EPS Gold Matte Metallic LE',
'RZR XP 1000 EPS High Lifter Edition',
'RZR XP 1000 EPS LE',
'RZR XP 1000 EPS Velocity Blue LE',
'RZR XP 4 1000 EPS',
'RZR XP 4 1000 EPS High Lifter Edition',
'RZR XP 4 Turbo EPS',
'RZR XP Turbo EPS',




]
years = list(range(2011, 2017))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#          Make                                  Model Vendor  \
# 0    Kawasaki                      Scrambler 500 4x4   NACH
# 1    Kawasaki                       Sportsman 500 HO   NACH
# 2    Kawasaki   Sportsman 500 HO Polaris Pursuite LE   NACH
# 3    Kawasaki               Sportsman 500 HO Touring   NACH
# 4    Kawasaki                         Ranger 570 EPS   NACH
# ..        ...                                    ...    ...
# 493  Kawasaki       RZR XP 1000 EPS Velocity Blue LE   NACH
# 494  Kawasaki                      RZR XP 4 1000 EPS   NACH
# 495  Kawasaki  RZR XP 4 1000 EPS High Lifter Edition   NACH
# 496  Kawasaki                     RZR XP 4 Turbo EPS   NACH
# 497  Kawasaki                       RZR XP Turbo EPS   NACH
#
#                        Vendor Code  Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03080REAROutboard.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.   ', 
    mpn='AT-03081',
    sku='121813',
    front_rear='FRONT',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = [
    
'Renegade 570 X mr',
'Outlander 650 X mr',
'Outlander 800R EFI X mr',
'Outlander 850 X mr',
'Outlander Max 1000 Limited',
'Renegade 1000 X mr',
'Defender HD10',
'Defender HD10 DPS',
'Defender HD10 XT',
'Defender HD10 XT CAB',
'Defender HD5',
'Defender HD5 DPS',
'Defender HD8',
'Defender HD8 DPS',
'Defender HD8 XT',
'Defender MAX HD10 DPS',
'Defender MAX HD10 XT',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Commander 800R',
'Commander 800R DPS',
'Commander 800R XT',
'Commander Max 800R DPS',
'Commander 1000',
'Commander 1000 DPS',
'Commander 1000 Limited',
'Commander 1000 X',
'Commander 1000 XT',
'Commander 1000 XT-P',
'Maverick Max 1000R',
'Maverick Max 1000R DPS',
'Maverick Max 1000R Turbo',
'Maverick Max 1000R Turbo X ds',
'Maverick Max 1000R Turbo X rs',
'Maverick Max 1000R X ds',
'Maverick Max 1000R X mr',
'Maverick Max 1000R X rs DPS',
'Maverick 1000R',
'Maverick 1000R DPS',
'Maverick 1000R X ds',
'Maverick 1000R X mr',
'Maverick 1000R X mr DPS',
'Maverick 1000R X rs',
'Maverick 1000R X rs DPS',
'Maverick 1000R X xc',
'Maverick 1000R X xc DPS',
'Maverick 1000R XC',
'Maverick 1000R xc DPS',
'Ranger 800 Crew',
'Ranger 800 Crew EPS',
'Ranger 800 Crew EPS LE',
'Ranger 800 EFI',
'Ranger 800 EFI EPS',
'Ranger 800 EFI EPS LE',
'Ranger 800 EFI LE',
'Ranger 800 EFI Mid-Size',
'Ranger 800 EFI Mid-Size LE',
'Ranger 800 EPS Mid-Size LE',
'Ranger 800 HD',
'Ranger 800 HD EPS',
'Ranger 800 XP',
'Ranger 800 XP EPS',
'Ranger 800 XP EPS LE',
'Ranger 800 XP LE'




]
years = list(range(2011, 2024))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#          Make                       Model Vendor  \
# 0    Kawasaki           Renegade 570 X mr   NACH
# 1    Kawasaki          Outlander 650 X mr   NACH
# 2    Kawasaki     Outlander 800R EFI X mr   NACH
# 3    Kawasaki          Outlander 850 X mr   NACH
# 4    Kawasaki  Outlander Max 1000 Limited   NACH
# ..        ...                         ...    ...
# 827  Kawasaki           Ranger 800 HD EPS   NACH
# 828  Kawasaki               Ranger 800 XP   NACH
# 829  Kawasaki           Ranger 800 XP EPS   NACH
# 830  Kawasaki        Ranger 800 XP EPS LE   NACH
# 831  Kawasaki            Ranger 800 XP LE   NACH
#
#                        Vendor Code  Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 3    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 4    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ..                             ...           ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03081FRONTiNboard.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.   ', 
    mpn='AT-03081',
    sku='121813',
    front_rear='FRONT',
    inboard_outboard='OUTBOARD'
)

# List of models and years
list_models = [
    
'Outlander Max 400 EFI',
'Outlander Max 400 EFI XT',
'Outlander 500 EFI',
'Outlander 500 EFI DPS',
'Outlander 500 EFI XT',
'Outlander 500 HO 4x4 EFI',
'Outlander 500 HO 4x4 EFI XT',
'Outlander 500 HO 4x4 EFI XT-P',
'Outlander Max 500 EFI',
'Outlander Max 500 EFI DPS',
'Outlander Max 500 EFI XT',
'Outlander Max 500 HO EFI',
'Outlander Max 500 HO EFI LTD',
'Outlander Max 500 HO EFI XT',
'Outlander Max 500 HO EFI XT-P',
'Renegade 500',
'Outlander L 570',
'Outlander L 570 DPS',
'Outlander L 570 LE',
'Outlander L 570 Mossy Oak Hunting Edition',
'Outlander L 570 X mr',
'Renegade 570',
'Renegade 570 X mr',
'Outlander 650 6x6 DPS',
'Outlander 650 6x6 XT',
'Renegade 850',
'Renegade 850 X xc',
'Outlander 1000 6x6 XT',
'Outlander 1000 DPS',
'Outlander 1000 EFI XT',
'Outlander 1000 EFI XT-P',
'Outlander 1000 X mr',
'Outlander 1000 X xc',
'Outlander 1000 XT',
'Outlander 1000 XT-P',
'Outlander 1000R X mr',
'Outlander 1000R X xc',
'Outlander 1000R XT',
'Outlander 1000R XT-P',
'Outlander Max 1000 6X6 XT',
'Outlander Max 1000 EFI DPS',
'Outlander Max 1000 EFI LTD',
'Outlander Max 1000 EFI XT',
'Outlander Max 1000 EFI XT-P',
'Outlander Max 1000 Limited',
'Outlander Max 1000 XT',
'Outlander Max 1000 XT-P',
'Outlander Max 1000R 6X6 XT',
'Outlander Max 1000R Limited',
'Outlander Max 1000R XT',
'Outlander Max 1000R XT-P',
'Renegade 1000',
'Renegade 1000 EFI X xc',
'Renegade 1000 X mr',
'Renegade 1000 X xc',
'Renegade 1000R X mr',
'Renegade 1000R X xc',
'Defender HD5',
'Defender HD5 DPS',
'Commander 800R',
'Commander 800R DPS',
'Commander 800R XT',
'Commander Max 800R DPS',
'Defender HD8',
'Defender HD8 DPS',
'Defender HD8 DPS CAB',
'Defender HD8 XT',
'Defender HD8 XT CAB',
'Defender MAX HD8',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Maverick Trail 800',
'Maverick Trail 800 DPS',
'Commander 1000',
'Commander 1000 DPS',
'Commander 1000 Limited',
'Commander 1000 Mossy Oak Hunting Edition',
'Commander 1000 XT',
'Commander 1000 XT-P',
'Commander 1000R DPS',
'Commander 1000R Limited',
'Commander 1000R Mossy Oak Hunting Edition',
'Commander 1000R X mr',
'Commander 1000R XT',
'Commander 1000R XT-P',
'Commander Max 1000 DPS',
'Commander Max 1000 Limited',
'Commander Max 1000 XT',
'Commander Max 1000R DPS',
'Commander Max 1000R Limited',
'Commander Max 1000R X mr',
'Commander Max 1000R XT',
'Commander Max 1000R XT-P',
'Defender HD10',
'Defender HD10 6X6 DPS',
'Defender HD10 6X6 Limited',
'Defender HD10 6X6 XT',
'Defender HD10 DPS',
'Defender HD10 Limited',
'Defender HD10 Mossy Oak Edition',
'Defender HD10 Mossy Oak Hunting Edition',
'Defender HD10 X mr',
'Defender HD10 X mr with Doors',
'Defender HD10 XT',
'Defender HD10 XT-P',
'Defender HD10 XT CAB',
'Defender MAX HD10 DPS',
'Defender MAX HD10 Limited',
'Defender MAX HD10 Lone Star',
'Defender MAX HD10 Lone Star CAB',
'Defender MAX HD10 X mr',
'Defender MAX HD10 X mr with Doors',
'Defender MAX HD10 XT',
'Defender MAX HD10 XT CAB',
'Defender PRO HD10',
'Defender PRO HD10 DPS',
'Defender PRO HD10 Limited',
'Defender PRO HD10 Lone Star',
'Defender PRO HD10 XT',
'Maverick 1000R',
'Maverick 1000R DPS',
'Maverick 1000R Turbo',
'Maverick 1000R Turbo X ds',
'Maverick 1000R Turbo X rs',
'Maverick 1000R X ds',
'Maverick 1000R X mr',
'Maverick 1000R X mr DPS',
'Maverick 1000R X rs',
'Maverick 1000R X rs DPS',
'Maverick 1000R X xc',
'Maverick 1000R X xc DPS',
'Maverick 1000R XC',
'Maverick 1000R xc DPS',
'Maverick Max 1000R',
'Maverick Max 1000R DPS',
'Maverick Max 1000R Turbo',
'Maverick Max 1000R Turbo X ds',
'Maverick Max 1000R Turbo X rs',
'Maverick Max 1000R X ds',
'Maverick Max 1000R X mr',
'Maverick Max 1000R X rs DPS',
'Maverick R',
'Maverick R X',
'Maverick R X RS',
'Maverick R X RS Smart-Shox',
'Maverick Sport 1000',
'Maverick Sport 1000 DPS',
'Maverick Sport 1000R DPS',
'Maverick Sport 1000R X mr',
'Maverick Sport 1000R X rc',
'Maverick Sport 1000R X xc',
'Maverick Sport Max 1000R DPS',
'Maverick Trail 1000',
'Maverick Trail 1000 DPS',
'Ranger 800 Crew',
'Ranger 800 EFI',
'Ranger 800 EFI EPS LE',
'Ranger 800 EFI Mid-Size',
'Ranger 800 EPS Mid-Size LE',
'Ranger Diesel',
'Ranger Diesel Crew',
'Ranger Diesel HST',
'Ranger Diesel HST Deluxe',
'Ranger 900-6 Crew',
'Ranger 900-6 Crew EPS',
'Ranger 900 Crew',
'Ranger 900 Crew EPS',
'Ranger 900 Crew EPS LE',
'YXC700 Viking VI',
'YXC700 Viking VI EPS',
'YXC700 Viking VI EPS Ranch Edition',
'YXC700 Viking VI EPS SE',
'YXM700 Viking',
'YXM700 Viking EPS',
'YXM700 Viking EPS Ranch Edition',
'YXM700 Viking EPS SE',
'YXM700 Viking EPS with Suntop',
'YXM700 Viking with Suntop',
'YXE70 Wolverine EPS',
'YXE70 Wolverine R-Spec',
'YXE70 Wolverine R-Spec EPS',
'YXE70 Wolverine R-Spec EPS SE'





]
years = list(range(2011, 2024))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#           Make                          Model Vendor  \
# 0     Kawasaki          Outlander Max 400 EFI   NACH
# 1     Kawasaki       Outlander Max 400 EFI XT   NACH
# 2     Kawasaki              Outlander 500 EFI   NACH
# 3     Kawasaki          Outlander 500 EFI DPS   NACH
# 4     Kawasaki           Outlander 500 EFI XT   NACH
# ...        ...                            ...    ...
# 2361  Kawasaki      YXM700 Viking with Suntop   NACH
# 2362  Kawasaki            YXE70 Wolverine EPS   NACH
# 2363  Kawasaki         YXE70 Wolverine R-Spec   NACH
# 2364  Kawasaki     YXE70 Wolverine R-Spec EPS   NACH
# 2365  Kawasaki  YXE70 Wolverine R-Spec EPS SE   NACH
#
#                         Vendor Code  Product Type  \
# 0     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 3     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 4     NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03081FRONTOUTBOARD.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

class Boot:
    def __init__(self, make, model, vendor, vendor_code, product_type, vendor_notes, mpn, sku, front_rear, inboard_outboard):
        self.make = make
        self.model = model
        self.vendor = vendor
        self.vendor_code = vendor_code
        self.product_type = product_type
        self.vendor_notes = vendor_notes
        self.mpn = mpn
        self.sku = sku
        self.front_rear = front_rear
        self.inboard_outboard = inboard_outboard

    def to_dict(self):
        return {
            'Make': [self.make],
            'Model': [self.model],
            'Vendor': [self.vendor],
            'Vendor Code': [self.vendor_code],
            'Product Type': [self.product_type],
            'Vendor Notes': [self.vendor_notes],
            'MPN': [self.mpn],
            'SKU': [self.sku],
            'FRONT/REAR': [self.front_rear],
            'INBOARD/OUTBOARD': [self.inboard_outboard]
        }

class BootGenerator:
    def __init__(self, boot_template, models, years):
        self.boot_template = boot_template
        self.models = models
        self.years = years

    def generate_boots(self):
        dfs = []
        for year in self.years:
            df_year = pd.concat([self.create_boot_df(model, year) for model in self.models], ignore_index=True)
            dfs.append(df_year)
        return pd.concat(dfs, ignore_index=True)

    def create_boot_df(self, model, year):
        boot_data = self.boot_template.to_dict()
        boot_data['Model'] = [model]
        boot_data['Year'] = [year]
        return pd.DataFrame(boot_data)

# Initialize the boot template
boot_template = Boot(
    make='Kawasaki',
    model='All Model',
    vendor='NACH',
    vendor_code='NACHMAN INTERNATIONAL CO. LTD',
    product_type='CV Boots Kit',
    vendor_notes='* OEM REPLACEMENT CV BOOT KITS. NO CUTTING OR TRIMMING NECESSARY. ; * EXCEEDS OEM QUALITY  ;* HUGE SELECTION OF ATV/UTV APPLICATIONS AVAILABLE ; * INCLUDES EVERYTHING YOU NEED TO REPLACE ONE CV BOOT:  BOOT,  CLAMPS, AND 100G OF GREASE.   ', 
    mpn='AT-03081',
    sku='121813',
    front_rear='REAR',
    inboard_outboard='INBOARD'
)

# List of models and years
list_models = [
    
'Outlander 450',
'Outlander 450 DPS',
'Outlander 450 Hunting Edition',
'Outlander 450 Mossy Oak Hunitng Edition',
'Outlander L 450',
'Outlander L 450 DPS',
'Outlander Max 450',
'Outlander Max 450 6X6 DPS',
'Outlander Max 450 DPS',
'Sportsman 550',
'Sportsman 550 EFI',
'Sportsman 550 EFI Touring w/ EPS',
'Sportsman 550 EFI w/ EPS',
'Sportsman 550 EPS',
'Sportsman 550 EPS Browning LE',
'Sportsman 550 EPS Orange Madness LE',
'Sportsman 550 EPS Stealth Black LE',
'Sportsman 550 Touring EPS',
'Sportsman 550 X2',
'Sportsman 550 X2 EPS',
'Scrambler 850',
'Scrambler 850 XP HO',
'Scrambler 850 XP HO EPS LE',
'Sportsman 850',
'Sportsman 850 EFI Touring EPS',
'Sportsman 850 EFI X2',
'Sportsman 850 EFI XP',
'Sportsman 850 EFI XP w/ EPS',
'Sportsman 850 High Lifter Edition',
'Sportsman 850 HO Touring EPS',
'Sportsman 850 HO Touring EPS Bronze Mist LE',
'Sportsman 850 HO Touring EPS Sunset Red LE',
'Sportsman 850 HO XP',
'Sportsman 850 HO XP EPS',
'Sportsman 850 HO XP EPS Browning LE',
'Sportsman 850 HO XP EPS Orange Madness LE',
'Sportsman 850 HO XP EPS Pearl White LE',
'Sportsman 850 HO XP EPS Stealth Black LE',
'Sportsman 850 Premium',
'Sportsman 850 SP',
'Sportsman 850 Touring',
'Sportsman 850 Touring SP',
'Sportsman 850 Ultimate Trail',
'Scrambler 1000 XP',
'Scrambler 1000 XP EPS',
'Scrambler 1000 XP S',
'Scrambler 1000 XP S LE',
'Sportsman 1000 Touring XP',
'Sportsman 1000 Touring XP Limited',
'Sportsman 1000 Touring XP Trail',
'Sportsman 1000 XP',
'Sportsman 1000 XP High Lifter Edition',
'Sportsman 1000 XP Hunt Edition',
'Sportsman 1000 XP Hunter Edition',
'Sportsman 1000 XP Premium',
'Sportsman 1000 XP Ride Command Edition',
'Sportsman 1000 XP S',
'Sportsman 1000 XP Ultimate Trail'

]
years = list(range(2011, 2024))

# Generate the DataFrame using OOP
generator = BootGenerator(boot_template, list_models, years)
final_df = generator.generate_boots()

# Display the final DataFrame
final_df
# Out:
#          Make                                    Model Vendor  \
# 0    Kawasaki                            Outlander 450   NACH
# 1    Kawasaki                        Outlander 450 DPS   NACH
# 2    Kawasaki            Outlander 450 Hunting Edition   NACH
# 3    Kawasaki  Outlander 450 Mossy Oak Hunitng Edition   NACH
# 4    Kawasaki                          Outlander L 450   NACH
# ..        ...                                      ...    ...
# 749  Kawasaki         Sportsman 1000 XP Hunter Edition   NACH
# 750  Kawasaki                Sportsman 1000 XP Premium   NACH
# 751  Kawasaki   Sportsman 1000 XP Ride Command Edition   NACH
# 752  Kawasaki                      Sportsman 1000 XP S   NACH
# 753  Kawasaki         Sportsman 1000 XP Ultimate Trail   NACH
#
#                        Vendor Code  Product Type  \
# 0    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 1    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# 2    NACHMAN INTERNATIONAL CO. LTD  CV Boots Kit
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\NEW TASK! Section 08\02_SECTION 08 - CV BOOTS KITS ( 12-20-23 )\Merge\AT-03081rearINBOARD.csv"
final_df.to_csv(file_path, index = False)
